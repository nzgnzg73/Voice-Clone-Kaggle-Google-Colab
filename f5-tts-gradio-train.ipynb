# %% [markdown]
# # F5-TTS (Gradio version)
#
# > (Created by GeleiaComPepino ❤️)
#
# *   Updated 03/11/2024
#
# ![Stickman Dançando](https://media1.tenor.com/m/Do2TZlXHC-kAAAAC/groove-stickman.gif)

# %% [markdown]
# # Install Dependencies and the repo

# %%
# !git clone https://github.com/SWivid/F5-TTS.git
# %cd F5-TTS
# git submodule update --init --recursive  # (optional, if need bigvgan)
# !pip install -e .
from IPython.display import clear_output
clear_output()

# %% [markdown]
# # Start the code webui

# %%
# !f5-tts_infer-gradio --share

# %% [markdown]
# # Credits
#
# Created by GeleiaComPepino
#
# Project github: https://github.com/SWivid/F5-TTS
#
# Thanks ❤️
